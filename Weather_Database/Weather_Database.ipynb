# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and Longitudes to a list 
coordinates = list(lat_lngs)

# %%
# Make a list to hold the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 792

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 2 of Set 1 | mfou
# Processing Record 3 of Set 1 | miguel auza
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | salalah
# Processing Record 7 of Set 1 | harrisonburg
# Processing Record 8 of Set 1 | angoche
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | collie
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | spirit river
# Processing Record 13 of Set 1 | jalu
# Processing Record 14 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 1 | barpeta
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | saint-pierre
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | bathsheba
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | chumikan
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | asfi
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | yamethin
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | shelburne
# Processing Record 34 of Set 1 | kemijarvi
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | westport
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | kupang
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | kathmandu
# Processing Record 42 of Set 1 | luanda
# Processing Record 43 of Set 1 | wencheng
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | villa bruzual
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | polohy
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | puerto escondido
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 2 | yaan
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | konya
# Processing Record 10 of Set 2 | bereda
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 2 | erzin
# Processing Record 15 of Set 2 | bull savanna
# Processing Record 16 of Set 2 | szamotuly
# Processing Record 17 of Set 2 | adeje
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | usinsk
# Processing Record 23 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 24 of Set 2 | boca do acre
# Processing Record 25 of Set 2 | norman wells
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | sungaipenuh
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | jiuquan
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | bara
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | galesong
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | sagone
# Processing Record 42 of Set 2 | yantzaza
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | lillesand
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | lata
# Processing Record 47 of Set 2 | arroyo
# Processing Record 48 of Set 2 | lavrentiya
# Processing Record 49 of Set 2 | ayan
# Processing Record 50 of Set 2 | xalpatlahuac
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | charleville-mezieres
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | egvekinot
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | bilibino
# Processing Record 9 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 3 | paamiut
# Processing Record 11 of Set 3 | santa lucia
# Processing Record 12 of Set 3 | gold coast
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | raudeberg
# Processing Record 15 of Set 3 | secunda
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | mae sai
# Processing Record 19 of Set 3 | henties bay
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | salinopolis
# Processing Record 22 of Set 3 | okha
# Processing Record 23 of Set 3 | jining
# Processing Record 24 of Set 3 | puerto narino
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | hastings
# Processing Record 27 of Set 3 | harper
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | napier
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | pringsewu
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | bongandanga
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | samana
# Processing Record 38 of Set 3 | mayo
# Processing Record 39 of Set 3 | bikaner
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | ca mau
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | kolpashevo
# Processing Record 48 of Set 3 | wexford
# Processing Record 49 of Set 3 | memari
# Processing Record 50 of Set 3 | sao felix do xingu
# Processing Record 1 of Set 4 | havelock
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | sahuaripa
# Processing Record 5 of Set 4 | maniitsoq
# Processing Record 6 of Set 4 | shimanovsk
# Processing Record 7 of Set 4 | herbrechtingen
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | brae
# Processing Record 10 of Set 4 | maryville
# Processing Record 11 of Set 4 | algeciras
# Processing Record 12 of Set 4 | xining
# Processing Record 13 of Set 4 | mogadishu
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | marawi
# Processing Record 16 of Set 4 | mankono
# Processing Record 17 of Set 4 | monroe
# Processing Record 18 of Set 4 | rodbyhavn
# Processing Record 19 of Set 4 | batemans bay
# Processing Record 20 of Set 4 | katangli
# Processing Record 21 of Set 4 | palomares
# Processing Record 22 of Set 4 | malindi
# Processing Record 23 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | roma
# Processing Record 29 of Set 4 | finschhafen
# Processing Record 30 of Set 4 | santa maria
# Processing Record 31 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 4 | bandarbeyla
# Processing Record 33 of Set 4 | grindavik
# Processing Record 34 of Set 4 | nikolskoye
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | kouango
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | villa corona
# Processing Record 39 of Set 4 | yablonovo
# Processing Record 40 of Set 4 | sambava
# Processing Record 41 of Set 4 | beloha
# Processing Record 42 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 4 | oswego
# Processing Record 46 of Set 4 | batesville
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | nuevo casas grandes
# Processing Record 2 of Set 5 | sharlyk
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | vranje
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | muros
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | chadiza
# Processing Record 10 of Set 5 | camopi
# Processing Record 11 of Set 5 | kamariotissa
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | goderich
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | tonekabon
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | ashland
# Processing Record 18 of Set 5 | mbekenyera
# Processing Record 19 of Set 5 | upernavik
# Processing Record 20 of Set 5 | lac du bonnet
# Processing Record 21 of Set 5 | healdsburg
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | taitung
# Processing Record 24 of Set 5 | hobyo
# Processing Record 25 of Set 5 | yumen
# Processing Record 26 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | chernyshevskiy
# Processing Record 28 of Set 5 | indiana
# Processing Record 29 of Set 5 | xichang
# Processing Record 30 of Set 5 | timmins
# Processing Record 31 of Set 5 | illapel
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | krasnoselkup
# Processing Record 34 of Set 5 | nishihara
# Processing Record 35 of Set 5 | lima
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | ahuimanu
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | coihaique
# Processing Record 40 of Set 5 | marsabit
# Processing Record 41 of Set 5 | fairbanks
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | tatarsk
# Processing Record 45 of Set 5 | mecca
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | saldanha
# Processing Record 49 of Set 5 | lashio
# Processing Record 50 of Set 5 | buchanan
# Processing Record 1 of Set 6 | changde
# Processing Record 2 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 6 | caravelas
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | cerbal
# City not found. Skipping...
# Processing Record 6 of Set 6 | rajauri
# Processing Record 7 of Set 6 | sulangan
# Processing Record 8 of Set 6 | cabo san lucas
# Processing Record 9 of Set 6 | ancud
# Processing Record 10 of Set 6 | atbasar
# Processing Record 11 of Set 6 | broome
# Processing Record 12 of Set 6 | gilgit
# Processing Record 13 of Set 6 | chickasha
# Processing Record 14 of Set 6 | malangali
# Processing Record 15 of Set 6 | fonte boa
# Processing Record 16 of Set 6 | jilib
# Processing Record 17 of Set 6 | zalari
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | swan river
# Processing Record 20 of Set 6 | dauriya
# Processing Record 21 of Set 6 | road town
# Processing Record 22 of Set 6 | baiyin
# Processing Record 23 of Set 6 | shahrud
# Processing Record 24 of Set 6 | laukaa
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | lesnoy
# Processing Record 27 of Set 6 | abu dhabi
# Processing Record 28 of Set 6 | college
# Processing Record 29 of Set 6 | kulhudhuffushi
# Processing Record 30 of Set 6 | arrecife
# Processing Record 31 of Set 6 | hithadhoo
# Processing Record 32 of Set 6 | karlstad
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | maarianhamina
# Processing Record 35 of Set 6 | labuhan
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 6 | jos
# Processing Record 39 of Set 6 | skelleftea
# Processing Record 40 of Set 6 | key largo
# Processing Record 41 of Set 6 | flin flon
# Processing Record 42 of Set 6 | mahibadhoo
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | xingcheng
# Processing Record 45 of Set 6 | gwadar
# Processing Record 46 of Set 6 | axim
# Processing Record 47 of Set 6 | kichera
# Processing Record 48 of Set 6 | kiama
# Processing Record 49 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 6 | baykit
# Processing Record 1 of Set 7 | sijunjung
# Processing Record 2 of Set 7 | monrovia
# Processing Record 3 of Set 7 | saurimo
# Processing Record 4 of Set 7 | ligayan
# Processing Record 5 of Set 7 | cayenne
# Processing Record 6 of Set 7 | celestun
# Processing Record 7 of Set 7 | vrangel
# Processing Record 8 of Set 7 | korla
# Processing Record 9 of Set 7 | olga
# Processing Record 10 of Set 7 | urubicha
# Processing Record 11 of Set 7 | nelson bay
# Processing Record 12 of Set 7 | arlit
# Processing Record 13 of Set 7 | el rosario
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | juarez
# Processing Record 16 of Set 7 | san cristobal
# Processing Record 17 of Set 7 | vanavara
# Processing Record 18 of Set 7 | boguchany
# Processing Record 19 of Set 7 | solntsevo
# Processing Record 20 of Set 7 | porto belo
# Processing Record 21 of Set 7 | birao
# Processing Record 22 of Set 7 | ayacucho
# Processing Record 23 of Set 7 | naryan-mar
# Processing Record 24 of Set 7 | pisco
# Processing Record 25 of Set 7 | grand gaube
# Processing Record 26 of Set 7 | necochea
# Processing Record 27 of Set 7 | srednekolymsk
# Processing Record 28 of Set 7 | iranshahr
# Processing Record 29 of Set 7 | cap-aux-meules
# Processing Record 30 of Set 7 | imbituba
# Processing Record 31 of Set 7 | tiksi
# Processing Record 32 of Set 7 | terrace
# Processing Record 33 of Set 7 | high level
# Processing Record 34 of Set 7 | banda aceh
# Processing Record 35 of Set 7 | norsup
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | kidal
# Processing Record 38 of Set 7 | lasa
# Processing Record 39 of Set 7 | lai
# Processing Record 40 of Set 7 | rassvet
# Processing Record 41 of Set 7 | nemuro
# Processing Record 42 of Set 7 | tautira
# Processing Record 43 of Set 7 | yeniseysk
# Processing Record 44 of Set 7 | amuntai
# Processing Record 45 of Set 7 | mchinji
# Processing Record 46 of Set 7 | ust-omchug
# Processing Record 47 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 7 | adet
# Processing Record 49 of Set 7 | cabedelo
# Processing Record 50 of Set 7 | mazarron
# Processing Record 1 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 8 | meulaboh
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | port blair
# Processing Record 5 of Set 8 | yerbogachen
# Processing Record 6 of Set 8 | tual
# Processing Record 7 of Set 8 | port hedland
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | ishigaki
# Processing Record 12 of Set 8 | urumqi
# Processing Record 13 of Set 8 | langsa
# Processing Record 14 of Set 8 | abeche
# Processing Record 15 of Set 8 | gobabis
# Processing Record 16 of Set 8 | port moresby
# Processing Record 17 of Set 8 | setermoen
# Processing Record 18 of Set 8 | paita
# Processing Record 19 of Set 8 | touros
# Processing Record 20 of Set 8 | puerto del rosario
# Processing Record 21 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 8 | rawson
# Processing Record 23 of Set 8 | villa rica
# Processing Record 24 of Set 8 | alice springs
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | panalingaan
# Processing Record 27 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 8 | mocuba
# Processing Record 29 of Set 8 | si satchanalai
# Processing Record 30 of Set 8 | bitung
# Processing Record 31 of Set 8 | badamdar
# Processing Record 32 of Set 8 | comarapa
# Processing Record 33 of Set 8 | jumla
# Processing Record 34 of Set 8 | moron
# Processing Record 35 of Set 8 | shubarkuduk
# Processing Record 36 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 37 of Set 8 | aktau
# Processing Record 38 of Set 8 | dubbo
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | bulgan
# Processing Record 41 of Set 8 | sandwick
# Processing Record 42 of Set 8 | norilsk
# Processing Record 43 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 44 of Set 8 | santander jimenez
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | jalingo
# Processing Record 47 of Set 8 | constitucion
# Processing Record 48 of Set 8 | deniliquin
# Processing Record 49 of Set 8 | cardston
# Processing Record 50 of Set 8 | trincomalee
# Processing Record 1 of Set 9 | kondinskoye
# Processing Record 2 of Set 9 | jiazi
# Processing Record 3 of Set 9 | barra da estiva
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | mao
# Processing Record 6 of Set 9 | hualmay
# Processing Record 7 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 9 | santa cruz cabralia
# Processing Record 9 of Set 9 | mexico
# Processing Record 10 of Set 9 | saint-joseph
# Processing Record 11 of Set 9 | luderitz
# Processing Record 12 of Set 9 | baley
# Processing Record 13 of Set 9 | alta floresta
# Processing Record 14 of Set 9 | matagami
# Processing Record 15 of Set 9 | kuusamo
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | carballo
# Processing Record 18 of Set 9 | revda
# Processing Record 19 of Set 9 | tanout
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | villa carlos paz
# Processing Record 23 of Set 9 | capoterra
# Processing Record 24 of Set 9 | sibolga
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | half moon bay
# Processing Record 27 of Set 9 | katsuura
# Processing Record 28 of Set 9 | gizo
# Processing Record 29 of Set 9 | flinders
# Processing Record 30 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 9 | chongoyape
# Processing Record 32 of Set 9 | kiruna
# Processing Record 33 of Set 9 | ilulissat
# Processing Record 34 of Set 9 | rio gallegos
# Processing Record 35 of Set 9 | kutum
# Processing Record 36 of Set 9 | kaele
# Processing Record 37 of Set 9 | nazare da mata
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | kununurra
# Processing Record 41 of Set 9 | sakaiminato
# Processing Record 42 of Set 9 | menongue
# Processing Record 43 of Set 9 | eyl
# Processing Record 44 of Set 9 | sale
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | pedernales
# Processing Record 47 of Set 9 | sobolevo
# Processing Record 48 of Set 9 | sinnamary
# Processing Record 49 of Set 9 | luena
# Processing Record 50 of Set 9 | moa
# Processing Record 1 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 10 | camacha
# Processing Record 3 of Set 10 | zhigansk
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | kuytun
# Processing Record 7 of Set 10 | muncar
# Processing Record 8 of Set 10 | ayer keroh
# Processing Record 9 of Set 10 | tete
# Processing Record 10 of Set 10 | koronadal
# Processing Record 11 of Set 10 | inta
# Processing Record 12 of Set 10 | kurtamysh
# Processing Record 13 of Set 10 | novoagansk
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 10 | pitimbu
# Processing Record 17 of Set 10 | dunedin
# Processing Record 18 of Set 10 | manyana
# Processing Record 19 of Set 10 | jurm
# Processing Record 20 of Set 10 | bielsko-biala
# Processing Record 21 of Set 10 | turukhansk
# Processing Record 22 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 10 | tombouctou
# Processing Record 24 of Set 10 | talnakh
# Processing Record 25 of Set 10 | burica
# City not found. Skipping...
# Processing Record 26 of Set 10 | lafayette
# Processing Record 27 of Set 10 | alyangula
# Processing Record 28 of Set 10 | diego de almagro
# Processing Record 29 of Set 10 | mehamn
# Processing Record 30 of Set 10 | turochak
# Processing Record 31 of Set 10 | chivasso
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | komsomolskiy
# Processing Record 35 of Set 10 | kailua
# Processing Record 36 of Set 10 | barcelos
# Processing Record 37 of Set 10 | batagay-alyta
# Processing Record 38 of Set 10 | khasan
# Processing Record 39 of Set 10 | klaksvik
# Processing Record 40 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 10 | bilma
# Processing Record 42 of Set 10 | awbari
# Processing Record 43 of Set 10 | barra dos coqueiros
# Processing Record 44 of Set 10 | linxia
# Processing Record 45 of Set 10 | bosobolo
# Processing Record 46 of Set 10 | aquiraz
# Processing Record 47 of Set 10 | jeremie
# Processing Record 48 of Set 10 | arys
# Processing Record 49 of Set 10 | xinzhou
# Processing Record 50 of Set 10 | waipawa
# Processing Record 1 of Set 11 | vidim
# Processing Record 2 of Set 11 | daru
# Processing Record 3 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 11 | mezen
# Processing Record 5 of Set 11 | valdobbiadene
# Processing Record 6 of Set 11 | hue
# Processing Record 7 of Set 11 | tarabuco
# Processing Record 8 of Set 11 | san fernando
# Processing Record 9 of Set 11 | kieta
# Processing Record 10 of Set 11 | beringovskiy
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | blind river
# Processing Record 13 of Set 11 | lisakovsk
# Processing Record 14 of Set 11 | ambon
# Processing Record 15 of Set 11 | ati
# Processing Record 16 of Set 11 | antofagasta
# Processing Record 17 of Set 11 | atambua
# Processing Record 18 of Set 11 | abu zabad
# Processing Record 19 of Set 11 | janakpur
# Processing Record 20 of Set 11 | el sauzal
# Processing Record 21 of Set 11 | hirara
# Processing Record 22 of Set 11 | mangai
# Processing Record 23 of Set 11 | igarka
# Processing Record 24 of Set 11 | comodoro rivadavia
# Processing Record 25 of Set 11 | pontian kecil
# Processing Record 26 of Set 11 | hay river
# Processing Record 27 of Set 11 | mufumbwe
# Processing Record 28 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 11 | talara
# Processing Record 30 of Set 11 | morondava
# Processing Record 31 of Set 11 | avanigadda
# Processing Record 32 of Set 11 | khash
# Processing Record 33 of Set 11 | iqaluit
# Processing Record 34 of Set 11 | lexington
# Processing Record 35 of Set 11 | hamilton
# Processing Record 36 of Set 11 | itambacuri
# Processing Record 37 of Set 11 | nanortalik
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | brawley
# Processing Record 40 of Set 11 | limbang
# Processing Record 41 of Set 11 | ust-nera
# Processing Record 42 of Set 11 | opuwo
# Processing Record 43 of Set 11 | ixtapa
# Processing Record 44 of Set 11 | north bend
# Processing Record 45 of Set 11 | balotra
# Processing Record 46 of Set 11 | takaka
# Processing Record 47 of Set 11 | tezu
# Processing Record 48 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 11 | kurtalan
# Processing Record 50 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 12 | oliver
# Processing Record 2 of Set 12 | bac lieu
# Processing Record 3 of Set 12 | tanah merah
# Processing Record 4 of Set 12 | verkhoyansk
# Processing Record 5 of Set 12 | araouane
# Processing Record 6 of Set 12 | baghdad
# Processing Record 7 of Set 12 | los llanos de aridane
# Processing Record 8 of Set 12 | rocha
# Processing Record 9 of Set 12 | fuerte olimpo
# Processing Record 10 of Set 12 | surt
# Processing Record 11 of Set 12 | dudinka
# Processing Record 12 of Set 12 | haicheng
# Processing Record 13 of Set 12 | emerald
# Processing Record 14 of Set 12 | sioux lookout
# Processing Record 15 of Set 12 | kilindoni
# Processing Record 16 of Set 12 | presidencia roque saenz pena
# Processing Record 17 of Set 12 | grants
# Processing Record 18 of Set 12 | leh
# Processing Record 19 of Set 12 | achinsk
# Processing Record 20 of Set 12 | atocha
# Processing Record 21 of Set 12 | gloversville
# Processing Record 22 of Set 12 | kulu
# Processing Record 23 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 12 | yafran
# Processing Record 25 of Set 12 | maniwaki
# Processing Record 26 of Set 12 | manta
# Processing Record 27 of Set 12 | poso
# Processing Record 28 of Set 12 | nizhniy odes
# Processing Record 29 of Set 12 | malartic
# Processing Record 30 of Set 12 | marienburg
# Processing Record 31 of Set 12 | murakami
# Processing Record 32 of Set 12 | saint-francois
# Processing Record 33 of Set 12 | ust-kulom
# Processing Record 34 of Set 12 | nampa
# Processing Record 35 of Set 12 | doka
# Processing Record 36 of Set 12 | deputatskiy
# Processing Record 37 of Set 12 | mandalgovi
# Processing Record 38 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 12 | vigrestad
# Processing Record 40 of Set 12 | snasa
# Processing Record 41 of Set 12 | saint-raymond
# Processing Record 42 of Set 12 | hohhot
# Processing Record 43 of Set 12 | ygatimi
# Processing Record 44 of Set 12 | cuamba
# Processing Record 45 of Set 12 | qujing
# Processing Record 46 of Set 12 | cabra
# Processing Record 47 of Set 12 | tilichiki
# Processing Record 48 of Set 12 | ust-maya
# Processing Record 49 of Set 12 | malkara
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | monterey
# Processing Record 2 of Set 13 | havre-saint-pierre
# Processing Record 3 of Set 13 | villazon
# Processing Record 4 of Set 13 | trastenik
# Processing Record 5 of Set 13 | kirakira
# Processing Record 6 of Set 13 | herat
# Processing Record 7 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 8 of Set 13 | asau
# Processing Record 9 of Set 13 | pochutla
# Processing Record 10 of Set 13 | alexandria
# Processing Record 11 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 13 | hellvik
# Processing Record 13 of Set 13 | metsovon
# City not found. Skipping...
# Processing Record 14 of Set 13 | avera
# Processing Record 15 of Set 13 | acarau
# Processing Record 16 of Set 13 | kijang
# Processing Record 17 of Set 13 | las cruces
# Processing Record 18 of Set 13 | takapau
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | poum
# Processing Record 21 of Set 13 | bundaberg
# Processing Record 22 of Set 13 | santa vitoria do palmar
# Processing Record 23 of Set 13 | tessalit
# Processing Record 24 of Set 13 | carnot
# Processing Record 25 of Set 13 | villa maria
# Processing Record 26 of Set 13 | svatove
# Processing Record 27 of Set 13 | pandan
# Processing Record 28 of Set 13 | zabid
# Processing Record 29 of Set 13 | aksu
# Processing Record 30 of Set 13 | tumen
# Processing Record 31 of Set 13 | pahrump
# Processing Record 32 of Set 13 | andenes
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | general pico
# Processing Record 35 of Set 13 | florianopolis
# Processing Record 36 of Set 13 | ahipara
# Processing Record 37 of Set 13 | bonanza
# Processing Record 38 of Set 13 | port hardy
# Processing Record 39 of Set 13 | kamiiso
# Processing Record 40 of Set 13 | port-gentil
# Processing Record 41 of Set 13 | agrado
# Processing Record 42 of Set 13 | oeiras
# Processing Record 43 of Set 13 | businga
# Processing Record 44 of Set 13 | vizinga
# Processing Record 45 of Set 13 | aklavik
# Processing Record 46 of Set 13 | boden
# Processing Record 47 of Set 13 | pervomayskoye
# Processing Record 48 of Set 13 | obera
# Processing Record 49 of Set 13 | boende
# Processing Record 50 of Set 13 | yanji
# Processing Record 1 of Set 14 | xuddur
# Processing Record 2 of Set 14 | beauchamps
# Processing Record 3 of Set 14 | balkanabat
# Processing Record 4 of Set 14 | russell
# Processing Record 5 of Set 14 | kisangani
# Processing Record 6 of Set 14 | natal
# Processing Record 7 of Set 14 | tibati
# Processing Record 8 of Set 14 | santarem
# Processing Record 9 of Set 14 | buraydah
# Processing Record 10 of Set 14 | desaguadero
# Processing Record 11 of Set 14 | visnes
# Processing Record 12 of Set 14 | watertown
# Processing Record 13 of Set 14 | jacareacanga
# Processing Record 14 of Set 14 | quebo
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | sumbe
# Processing Record 17 of Set 14 | kahului
# Processing Record 18 of Set 14 | turayf
# Processing Record 19 of Set 14 | mbaiki
# Processing Record 20 of Set 14 | primorskiy
# Processing Record 21 of Set 14 | takoradi
# Processing Record 22 of Set 14 | piterka
# Processing Record 23 of Set 14 | thabazimbi
# Processing Record 24 of Set 14 | ascension
# Processing Record 25 of Set 14 | lokosovo
# Processing Record 26 of Set 14 | loandjili
# Processing Record 27 of Set 14 | labuan
# Processing Record 28 of Set 14 | chikwawa
# Processing Record 29 of Set 14 | hvolsvollur
# Processing Record 30 of Set 14 | carauari
# Processing Record 31 of Set 14 | shingu
# Processing Record 32 of Set 14 | vao
# Processing Record 33 of Set 14 | pacific grove
# Processing Record 34 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 14 | kloulklubed
# Processing Record 36 of Set 14 | messina
# Processing Record 37 of Set 14 | imeni babushkina
# Processing Record 38 of Set 14 | mangochi
# Processing Record 39 of Set 14 | varhaug
# Processing Record 40 of Set 14 | zhongshu
# Processing Record 41 of Set 14 | kraksaan
# Processing Record 42 of Set 14 | bangui
# Processing Record 43 of Set 14 | staunton
# Processing Record 44 of Set 14 | apac
# Processing Record 45 of Set 14 | essau
# Processing Record 46 of Set 14 | vesyegonsk
# Processing Record 47 of Set 14 | luganville
# Processing Record 48 of Set 14 | kaberamaido
# Processing Record 49 of Set 14 | chimbote
# Processing Record 50 of Set 14 | kabo
# Processing Record 1 of Set 15 | saint anthony
# Processing Record 2 of Set 15 | benguela
# Processing Record 3 of Set 15 | port shepstone
# Processing Record 4 of Set 15 | polyarnyy
# Processing Record 5 of Set 15 | neiafu
# Processing Record 6 of Set 15 | khandyga
# Processing Record 7 of Set 15 | pavlysh
# Processing Record 8 of Set 15 | teahupoo
# Processing Record 9 of Set 15 | skibbereen
# Processing Record 10 of Set 15 | liverpool
# Processing Record 11 of Set 15 | noumea
# Processing Record 12 of Set 15 | waingapu
# Processing Record 13 of Set 15 | omutinskoye
# City not found. Skipping...
# Processing Record 14 of Set 15 | palu
# Processing Record 15 of Set 15 | san rafael
# Processing Record 16 of Set 15 | roebourne
# Processing Record 17 of Set 15 | santo augusto
# Processing Record 18 of Set 15 | gulfport
# Processing Record 19 of Set 15 | tateyama
# Processing Record 20 of Set 15 | nizip
# Processing Record 21 of Set 15 | katherine
# Processing Record 22 of Set 15 | tabuk
# Processing Record 23 of Set 15 | nhulunbuy
# Processing Record 24 of Set 15 | rawah
# Processing Record 25 of Set 15 | kostroma
# Processing Record 26 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 15 | simpang
# Processing Record 28 of Set 15 | margate
# Processing Record 29 of Set 15 | mocajuba
# Processing Record 30 of Set 15 | neryungri
# Processing Record 31 of Set 15 | shieli
# Processing Record 32 of Set 15 | mayor pablo lagerenza
# Processing Record 33 of Set 15 | cheyenne
# Processing Record 34 of Set 15 | mumbwa
# Processing Record 35 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 36 of Set 15 | ternate
# Processing Record 37 of Set 15 | chipinge
# Processing Record 38 of Set 15 | dakar
# Processing Record 39 of Set 15 | havoysund
# Processing Record 40 of Set 15 | cortes
# Processing Record 41 of Set 15 | moura
# Processing Record 42 of Set 15 | manado
# Processing Record 43 of Set 15 | eureka
# Processing Record 44 of Set 15 | port said
# Processing Record 45 of Set 15 | warrnambool
# Processing Record 46 of Set 15 | eenhana
# Processing Record 47 of Set 15 | mordovo
# Processing Record 48 of Set 15 | kyren
# Processing Record 49 of Set 15 | powell
# Processing Record 50 of Set 15 | banjar
# Processing Record 1 of Set 16 | dubai
# Processing Record 2 of Set 16 | tulun
# Processing Record 3 of Set 16 | lloydminster
# Processing Record 4 of Set 16 | acajutla
# Processing Record 5 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 16 | makakilo city
# Processing Record 7 of Set 16 | berdigestyakh
# Processing Record 8 of Set 16 | ayapel
# Processing Record 9 of Set 16 | shahr-e babak
# Processing Record 10 of Set 16 | biggar
# Processing Record 11 of Set 16 | placerville
# Processing Record 12 of Set 16 | romans-sur-isere
# Processing Record 13 of Set 16 | mikhaylovka
# Processing Record 14 of Set 16 | along
# Processing Record 15 of Set 16 | adre
# Processing Record 16 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 16 | kavaratti
# Processing Record 18 of Set 16 | borlange
# City not found. Skipping...
# Processing Record 19 of Set 16 | savino
# Processing Record 20 of Set 16 | mitu
# Processing Record 21 of Set 16 | ndele
# Processing Record 22 of Set 16 | bijapur
# Processing Record 23 of Set 16 | vesele
# Processing Record 24 of Set 16 | ugra
# Processing Record 25 of Set 16 | smithers
# Processing Record 26 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 16 | balabac
# Processing Record 28 of Set 16 | kesan
# Processing Record 29 of Set 16 | krasavino
# Processing Record 30 of Set 16 | vokhma
# Processing Record 31 of Set 16 | baisha
# Processing Record 32 of Set 16 | balderas
# City not found. Skipping...
# Processing Record 33 of Set 16 | nyimba
# Processing Record 34 of Set 16 | boulder city
# Processing Record 35 of Set 16 | casas grandes
# Processing Record 36 of Set 16 | coacoatzintla
# Processing Record 37 of Set 16 | suzhou
# Processing Record 38 of Set 16 | rovinj
# Processing Record 39 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 16 | itarema
# Processing Record 41 of Set 16 | kenai
# Processing Record 42 of Set 16 | oda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Mfou      CM   3.7159   11.6427     70.02        97         100
# 1     Miguel Auza      MX  24.2933 -103.4503     76.80        32          93
# 2     Tuktoyaktuk      CA  69.4541 -133.0374     14.00        85         100
# 3          Albany      US  42.6001  -73.9662     54.25        85         100
# 4         Salalah      OM  17.0151   54.0924     84.29        70          20
# 5    Harrisonburg      US  38.4496  -78.8689     58.33        91         100
# 6         Angoche      MZ -16.2325   39.9086     76.91        87         100
# 7  Saint-Philippe      RE -21.3585   55.7679     73.22        82          37
# 8          Collie      AU -33.3667  116.1500     53.35        79          98
# 9      Sao Filipe      CV  14.8961  -24.4956     75.81        69          20
#
#    Wind Speed Current Description
# 0        3.87          light rain
# 1       12.50     overcast clouds
# 2        8.05                 fog
# 3        1.86     overcast clouds
# 4        4.61          few clouds
# 5        3.44          light rain
# 6        7.67     overcast clouds
# 7       11.36          light rain
# 8        2.44     overcast clouds
# 9       14.14          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
